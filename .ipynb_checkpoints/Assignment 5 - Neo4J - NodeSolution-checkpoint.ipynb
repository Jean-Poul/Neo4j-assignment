# %% [markdown]
# # Assignment 5 - Neo4j
#
# - Allan Simonsen
# - Jean-Poul Leth-Møller
# - Magda Aleksandra Wawrzak
# - Nina Lisakowski

# %% [markdown]
#  # 1. Import of libraries

# %%
# import pandas for structuring the data
import pandas as pd

import numpy as np

from py2neo import Graph,Node,Relationship

# %% [markdown]
# # 2. import of dataset from CSV

# %%
game_dataset = pd.read_csv('../sample-data/data/Sample_Game_1/Sample_Game_1_RawEventsData.csv', delimiter=",")

# %%
game_dataset.head(5)
# Out:
#    Team       Type   Subtype  Period  Start Frame  Start Time [s]  End Frame  \
# 0  Away  SET PIECE  KICK OFF       1            1            0.04          0
# 1  Away       PASS       NaN       1            1            0.04          3
# 2  Away       PASS       NaN       1            3            0.12         17
# 3  Away       PASS       NaN       1           45            1.80         61
# 4  Away       PASS       NaN       1           77            3.08         96
#
#    End Time [s]      From        To  Start X  Start Y  End X  End Y
# 0          0.00  Player19       NaN      NaN      NaN    NaN    NaN
# 1          0.12  Player19  Player21     0.45     0.39   0.55   0.43
# 2          0.68  Player21  Player15     0.55     0.43   0.58   0.21
# 3          2.44  Player15  Player19     0.55     0.19   0.45   0.31
# 4          3.84  Player19  Player21     0.45     0.32   0.49   0.47

# %%
game_dataset.tail(5)
# Out:
#       Team       Type       Subtype  Period  Start Frame  Start Time [s]  \
# 1740  Home       PASS           NaN       2       143361         5734.44
# 1741  Home       PASS           NaN       2       143578         5743.12
# 1742  Home  BALL LOST  INTERCEPTION       2       143598         5743.92
# 1743  Away   RECOVERY       BLOCKED       2       143617         5744.68
# 1744  Away   BALL OUT           NaN       2       143622         5744.88
#
#       End Frame  End Time [s]      From        To  Start X  Start Y  End X  \
# 1740     143483       5739.32  Player12  Player13     0.60     0.33   0.19
# 1741     143593       5743.72  Player13   Player4     0.09     0.88   0.14
# 1742     143618       5744.72   Player4       NaN     0.13     0.69   0.07
# 1743     143617       5744.68  Player16       NaN     0.05     0.62    NaN
# 1744     143630       5745.20  Player16       NaN     0.05     0.63   0.03
#
#       End Y
# 1740   0.95
# 1741   0.69
# 1742   0.61
# 1743    NaN
# 1744   1.01

# %%
game_dataset.shape
# Out:
# (1745, 14)

# %%
game_dataset['From'].unique()
# Out:
# array(['Player19', 'Player21', 'Player15', 'Player22', 'Player17',
#        'Player2', 'Player16', 'Player18', 'Player9', 'Player10',
#        'Player20', 'Player5', 'Player6', 'Player8', 'Player25', 'Player1',
#        'Player7', 'Player4', 'Player3', 'Player24', 'Player23',
#        'Player11', 'Player12', 'Player27', 'Player13', 'Player26',
#        'Player14', 'Player28'], dtype=object)

# %%
game_dataset['Type'].unique()
# Out:
# array(['SET PIECE', 'PASS', 'BALL LOST', 'RECOVERY', 'CHALLENGE',
#        'BALL OUT', 'SHOT', 'FAULT RECEIVED', 'CARD'], dtype=object)

# %% [markdown]
# # 3. Connection to database

# %%
graph = Graph('bolt://localhost:7687', auth=('neo4j', 'root123'))

# %% [markdown]
# # 4. Create Player nodes

# %% [markdown]
# We decided to make all player as seperate nodes.
# furtermore we decided to make each event (PASS, SET KICK, Challenge, etc) as a new node with the time property and a relationship to and from related players.
# The following picture show the setup with the PASS event.
# ![Graph Setup](GraphSetup.png)

# %%
for i in game_dataset['From'].unique():
    print(i)
    try:
        new_player = Node("player",name=i)
        tx=graph.begin()
        tx.create(new_player)
        graph.commit(tx)
    except:
        print('Player already Exist')
# Out:
# Player19
# Player21
# Player15
# Player22
# Player17
# Player2
# Player16
# Player18
# Player9
# Player10
# Player20
# Player5
# Player6
# Player8
# Player25
# Player1
# Player7
# Player4
# Player3
# Player24
# Player23
# Player11
# Player12
# Player27
# Player13
# Player26
# Player14
# Player28

# %% [markdown]
# # 5. Create Relationships and Event Nodes

# %%
for i in game_dataset.itertuples():
    try:
        fromPlayer = graph.nodes.match("player", name=i.From).first()
        toPlayer = graph.nodes.match("player", name=i.To).first()
        new_Event_node = Node(i.Type, name=i.Type, subtype=i.Subtype, team=i.Team, period=i.Period, starttime=i._6, endtime=i._8)
        relationshipfrom = Relationship(fromPlayer, i.Type, new_Event_node)
        tx=graph.begin()
        tx.create(new_Event_node)
        tx.create(relationshipfrom)
        if(toPlayer is not None):
            relationshipTo = Relationship(new_Event_node, i.Type, toPlayer)
            tx.create(relationshipTo)
        graph.commit(tx)
        print("Event Done")
    except BaseException as E:
        print(E)
# Out:
# Pandas(Index=0, Team='Away', Type='SET PIECE', Subtype='KICK OFF', Period=1, _5=1, _6=0.04, _7=0, _8=0.0, From='Player19', To=nan, _11=nan, _12=nan, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=1, _6=0.04, _7=3, _8=0.12, From='Player19', To='Player21', _11=0.45, _12=0.39, _13=0.55, _14=0.43)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=2, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=3, _6=0.12, _7=17, _8=0.68, From='Player21', To='Player15', _11=0.55, _12=0.43, _13=0.58, _14=0.21)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=3, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=45, _6=1.8, _7=61, _8=2.44, From='Player15', To='Player19', _11=0.55, _12=0.19, _13=0.45, _14=0.31)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=4, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=77, _6=3.08, _7=96, _8=3.84, From='Player19', To='Player21', _11=0.45, _12=0.32, _13=0.49, _14=0.47)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=5, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=191, _6=7.64, _7=217, _8=8.68, From='Player21', To='Player22', _11=0.4, _12=0.73, _13=0.32, _14=0.98)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=6, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=279, _6=11.16, _7=303, _8=12.12, From='Player22', To='Player17', _11=0.39, _12=0.96, _13=0.49, _14=0.98)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=7, Team='Away', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=346, _6=13.84, _7=380, _8=15.2, From='Player17', To=nan, _11=0.51, _12=0.97, _13=0.27, _14=0.75)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=8, Team='Home', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=378, _6=15.12, _7=378, _8=15.12, From='Player2', To=nan, _11=0.27, _12=0.78, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=9, Team='Home', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=378, _6=15.12, _7=452, _8=18.08, From='Player2', To=nan, _11=0.27, _12=0.78, _13=0.59, _14=0.64)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=10, Team='Away', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=453, _6=18.12, _7=453, _8=18.12, From='Player16', To=nan, _11=0.57, _12=0.67, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=11, Team='Away', Type='BALL LOST', Subtype='HEAD-INTERCEPTION', Period=1, _5=453, _6=18.12, _7=497, _8=19.88, From='Player16', To=nan, _11=0.57, _12=0.67, _13=0.33, _14=0.65)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=12, Team='Away', Type='CHALLENGE', Subtype='AERIAL-LOST', Period=1, _5=497, _6=19.88, _7=497, _8=19.88, From='Player18', To=nan, _11=0.38, _12=0.67, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=13, Team='Home', Type='CHALLENGE', Subtype='AERIAL-WON', Period=1, _5=498, _6=19.92, _7=498, _8=19.92, From='Player2', To=nan, _11=0.36, _12=0.67, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=14, Team='Home', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=498, _6=19.92, _7=498, _8=19.92, From='Player2', To=nan, _11=0.36, _12=0.67, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=15, Team='Home', Type='PASS', Subtype='HEAD', Period=1, _5=498, _6=19.92, _7=536, _8=21.44, From='Player2', To='Player9', _11=0.36, _12=0.67, _13=0.53, _14=0.59)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=16, Team='Home', Type='PASS', Subtype=nan, Period=1, _5=536, _6=21.44, _7=556, _8=22.24, From='Player9', To='Player10', _11=0.53, _12=0.59, _13=0.5, _14=0.65)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=17, Team='Home', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=572, _6=22.88, _7=616, _8=24.64, From='Player10', To=nan, _11=0.5, _12=0.65, _13=0.67, _14=0.44)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=18, Team='Away', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=618, _6=24.72, _7=618, _8=24.72, From='Player16', To=nan, _11=0.64, _12=0.46, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=19, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=763, _6=30.52, _7=784, _8=31.36, From='Player16', To='Player19', _11=0.58, _12=0.27, _13=0.51, _14=0.33)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=20, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=784, _6=31.36, _7=804, _8=32.16, From='Player19', To='Player20', _11=0.51, _12=0.33, _13=0.57, _14=0.47)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=21, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=834, _6=33.36, _7=881, _8=35.24, From='Player20', To='Player22', _11=0.53, _12=0.53, _13=0.44, _14=0.92)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=22, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=976, _6=39.04, _7=1010, _8=40.4, From='Player22', To='Player17', _11=0.36, _12=0.96, _13=0.48, _14=0.86)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=23, Team='Away', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=1110, _6=44.4, _7=1134, _8=45.36, From='Player17', To=nan, _11=0.42, _12=0.79, _13=0.31, _14=0.84)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=24, Team='Home', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=1134, _6=45.36, _7=1134, _8=45.36, From='Player5', To=nan, _11=0.32, _12=0.89, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=25, Team='Home', Type='PASS', Subtype='HEAD', Period=1, _5=1134, _6=45.36, _7=1154, _8=46.16, From='Player5', To='Player6', _11=0.32, _12=0.89, _13=0.31, _14=0.78)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=26, Team='Home', Type='PASS', Subtype=nan, Period=1, _5=1154, _6=46.16, _7=1177, _8=47.08, From='Player6', To='Player10', _11=0.31, _12=0.78, _13=0.41, _14=0.74)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=27, Team='Home', Type='PASS', Subtype=nan, Period=1, _5=1226, _6=49.04, _7=1266, _8=50.64, From='Player10', To='Player8', _11=0.46, _12=0.68, _13=0.56, _14=0.34)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=28, Team='Home', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=1370, _6=54.8, _7=1375, _8=55.0, From='Player8', To=nan, _11=0.86, _12=0.26, _13=0.88, _14=0.28)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=29, Team='Away', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=1374, _6=54.96, _7=1374, _8=54.96, From='Player15', To=nan, _11=0.87, _12=0.29, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=30, Team='Away', Type='BALL OUT', Subtype=nan, Period=1, _5=1374, _6=54.96, _7=1425, _8=57.0, From='Player15', To=nan, _11=0.87, _12=0.29, _13=1.05, _14=0.17)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=31, Team='Home', Type='SET PIECE', Subtype='CORNER KICK', Period=1, _5=2143, _6=85.72, _7=2143, _8=85.72, From='Player6', To=nan, _11=nan, _12=nan, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=32, Team='Home', Type='PASS', Subtype=nan, Period=1, _5=2143, _6=85.72, _7=2184, _8=87.36, From='Player6', To='Player10', _11=1.0, _12=0.01, _13=0.9, _14=0.09)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=33, Team='Home', Type='PASS', Subtype='CROSS', Period=1, _5=2263, _6=90.52, _7=2289, _8=91.56, From='Player10', To='Player9', _11=0.89, _12=0.14, _13=0.92, _14=0.47)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=34, Team='Home', Type='SHOT', Subtype='HEAD-ON TARGET-GOAL', Period=1, _5=2289, _6=91.56, _7=2309, _8=92.36, From='Player9', To=nan, _11=0.92, _12=0.47, _13=1.01, _14=0.55)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=35, Team='Away', Type='SET PIECE', Subtype='KICK OFF', Period=1, _5=3675, _6=147.0, _7=3675, _8=147.0, From='Player19', To=nan, _11=nan, _12=nan, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=36, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=3675, _6=147.0, _7=3703, _8=148.12, From='Player19', To='Player21', _11=0.49, _12=0.5, _13=0.58, _14=0.52)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=37, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=3780, _6=151.2, _7=3805, _8=152.2, From='Player21', To='Player20', _11=0.57, _12=0.53, _13=0.58, _14=0.73)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=38, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=3829, _6=153.16, _7=3854, _8=154.16, From='Player20', To='Player22', _11=0.57, _12=0.76, _13=0.52, _14=0.98)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=39, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=3882, _6=155.28, _7=3907, _8=156.28, From='Player22', To='Player17', _11=0.55, _12=0.95, _13=0.69, _14=0.87)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=40, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=3930, _6=157.2, _7=3994, _8=159.76, From='Player17', To='Player25', _11=0.71, _12=0.86, _13=0.93, _14=0.55)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=41, Team='Away', Type='BALL OUT', Subtype=nan, Period=1, _5=4093, _6=163.72, _7=4164, _8=166.56, From='Player25', To=nan, _11=0.93, _12=0.56, _13=0.49, _14=1.04)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=42, Team='Home', Type='SET PIECE', Subtype='THROW IN', Period=1, _5=4386, _6=175.44, _7=4386, _8=175.44, From='Player1', To=nan, _11=nan, _12=nan, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=43, Team='Home', Type='PASS', Subtype=nan, Period=1, _5=4386, _6=175.44, _7=4445, _8=177.8, From='Player1', To='Player10', _11=0.49, _12=1.01, _13=0.55, _14=0.84)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=44, Team='Home', Type='BALL LOST', Subtype=nan, Period=1, _5=4445, _6=177.8, _7=4453, _8=178.12, From='Player10', To=nan, _11=0.55, _12=0.84, _13=0.57, _14=0.78)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=45, Team='Away', Type='RECOVERY', Subtype=nan, Period=1, _5=4452, _6=178.08, _7=4452, _8=178.08, From='Player19', To=nan, _11=0.56, _12=0.82, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=46, Team='Away', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=4489, _6=179.56, _7=4518, _8=180.72, From='Player19', To=nan, _11=0.54, _12=0.87, _13=0.48, _14=0.85)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=47, Team='Home', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=4516, _6=180.64, _7=4516, _8=180.64, From='Player1', To=nan, _11=0.5, _12=0.87, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=48, Team='Home', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=4620, _6=184.8, _7=4679, _8=187.16, From='Player1', To=nan, _11=0.37, _12=0.97, _13=0.65, _14=0.92)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=49, Team='Away', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=4679, _6=187.16, _7=4679, _8=187.16, From='Player17', To=nan, _11=0.62, _12=0.92, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=50, Team='Away', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=4709, _6=188.36, _7=4749, _8=189.96, From='Player17', To=nan, _11=0.6, _12=0.95, _13=0.36, _14=0.78)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=51, Team='Home', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=4751, _6=190.04, _7=4751, _8=190.04, From='Player7', To=nan, _11=0.39, _12=0.78, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=52, Team='Home', Type='BALL OUT', Subtype=nan, Period=1, _5=4751, _6=190.04, _7=4836, _8=193.44, From='Player7', To=nan, _11=0.39, _12=0.78, _13=0.67, _14=1.03)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=53, Team='Away', Type='SET PIECE', Subtype='THROW IN', Period=1, _5=5057, _6=202.28, _7=5057, _8=202.28, From='Player22', To=nan, _11=nan, _12=nan, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=54, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=5057, _6=202.28, _7=5081, _8=203.24, From='Player22', To='Player19', _11=0.58, _12=1.01, _13=0.57, _14=0.89)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=55, Team='Away', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=5081, _6=203.24, _7=5150, _8=206.0, From='Player19', To=nan, _11=0.57, _12=0.89, _13=0.25, _14=0.84)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=56, Team='Home', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=5149, _6=205.96, _7=5149, _8=205.96, From='Player2', To=nan, _11=0.24, _12=0.82, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=57, Team='Home', Type='PASS', Subtype=nan, Period=1, _5=5149, _6=205.96, _7=5202, _8=208.08, From='Player2', To='Player1', _11=0.24, _12=0.82, _13=0.32, _14=0.89)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=58, Team='Home', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=5202, _6=208.08, _7=5228, _8=209.12, From='Player1', To=nan, _11=0.32, _12=0.89, _13=0.33, _14=0.84)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=59, Team='Home', Type='CHALLENGE', Subtype='GROUND-LOST', Period=1, _5=5228, _6=209.12, _7=5228, _8=209.12, From='Player6', To=nan, _11=0.36, _12=0.82, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=60, Team='Away', Type='CHALLENGE', Subtype='GROUND-WON', Period=1, _5=5228, _6=209.12, _7=5228, _8=209.12, From='Player19', To=nan, _11=0.36, _12=0.83, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=61, Team='Away', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=5228, _6=209.12, _7=5228, _8=209.12, From='Player19', To=nan, _11=0.36, _12=0.83, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=62, Team='Away', Type='BALL LOST', Subtype=nan, Period=1, _5=5228, _6=209.12, _7=5263, _8=210.52, From='Player19', To=nan, _11=0.36, _12=0.83, _13=0.28, _14=0.83)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=63, Team='Home', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=5263, _6=210.52, _7=5263, _8=210.52, From='Player1', To=nan, _11=0.29, _12=0.85, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=64, Team='Home', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=5316, _6=212.64, _7=5384, _8=215.36, From='Player1', To=nan, _11=0.26, _12=0.96, _13=0.64, _14=0.88)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=65, Team='Away', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=5385, _6=215.4, _7=5385, _8=215.4, From='Player17', To=nan, _11=0.59, _12=0.89, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=66, Team='Away', Type='PASS', Subtype='HEAD', Period=1, _5=5385, _6=215.4, _7=5412, _8=216.48, From='Player17', To='Player20', _11=0.59, _12=0.89, _13=0.54, _14=0.85)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=67, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=5431, _6=217.24, _7=5471, _8=218.84, From='Player20', To='Player18', _11=0.55, _12=0.83, _13=0.45, _14=0.5)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=68, Team='Away', Type='BALL LOST', Subtype=nan, Period=1, _5=5507, _6=220.28, _7=5517, _8=220.68, From='Player18', To=nan, _11=0.38, _12=0.47, _13=0.28, _14=0.41)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=69, Team='Home', Type='RECOVERY', Subtype=nan, Period=1, _5=5520, _6=220.8, _7=5520, _8=220.8, From='Player4', To=nan, _11=0.3, _12=0.43, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=70, Team='Home', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=5520, _6=220.8, _7=5550, _8=222.0, From='Player4', To=nan, _11=0.3, _12=0.43, _13=0.28, _14=0.52)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=71, Team='Away', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=5549, _6=221.96, _7=5549, _8=221.96, From='Player18', To=nan, _11=0.29, _12=0.49, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=72, Team='Home', Type='CHALLENGE', Subtype='TACKLE-WON', Period=1, _5=5627, _6=225.08, _7=5627, _8=225.08, From='Player1', To=nan, _11=0.14, _12=0.6, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=73, Team='Home', Type='RECOVERY', Subtype='THEFT', Period=1, _5=5627, _6=225.08, _7=5627, _8=225.08, From='Player1', To=nan, _11=0.14, _12=0.6, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=74, Team='Home', Type='PASS', Subtype=nan, Period=1, _5=5627, _6=225.08, _7=5663, _8=226.52, From='Player1', To='Player2', _11=0.14, _12=0.6, _13=0.18, _14=0.53)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=75, Team='Away', Type='CHALLENGE', Subtype='TACKLE-LOST', Period=1, _5=5628, _6=225.12, _7=5628, _8=225.12, From='Player18', To=nan, _11=0.15, _12=0.56, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=76, Team='Away', Type='BALL LOST', Subtype='THEFT', Period=1, _5=5628, _6=225.12, _7=5628, _8=225.12, From='Player18', To=nan, _11=0.15, _12=0.56, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=77, Team='Home', Type='PASS', Subtype=nan, Period=1, _5=5663, _6=226.52, _7=5685, _8=227.4, From='Player2', To='Player8', _11=0.18, _12=0.53, _13=0.24, _14=0.4)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=78, Team='Home', Type='PASS', Subtype=nan, Period=1, _5=5761, _6=230.44, _7=5809, _8=232.36, From='Player8', To='Player10', _11=0.39, _12=0.29, _13=0.6, _14=0.09)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=79, Team='Home', Type='SHOT', Subtype='OFF TARGET-OUT', Period=1, _5=5923, _6=236.92, _7=5953, _8=238.12, From='Player10', To=nan, _11=0.84, _12=0.27, _13=1.04, _14=0.6)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=80, Team='Away', Type='RECOVERY', Subtype=nan, Period=1, _5=6685, _6=267.4, _7=6685, _8=267.4, From='Player25', To=nan, _11=0.95, _12=0.45, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=81, Team='Away', Type='PASS', Subtype='GOAL KICK', Period=1, _5=6685, _6=267.4, _7=6779, _8=271.16, From='Player25', To='Player18', _11=0.95, _12=0.45, _13=0.53, _14=0.04)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=82, Team='Away', Type='BALL LOST', Subtype='HEAD', Period=1, _5=6779, _6=271.16, _7=6844, _8=273.76, From='Player18', To=nan, _11=0.53, _12=0.04, _13=0.57, _14=0.31)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=83, Team='Home', Type='RECOVERY', Subtype=nan, Period=1, _5=6844, _6=273.76, _7=6844, _8=273.76, From='Player6', To=nan, _11=0.54, _12=0.3, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=84, Team='Away', Type='CHALLENGE', Subtype='GROUND-WON', Period=1, _5=6863, _6=274.52, _7=6863, _8=274.52, From='Player21', To=nan, _11=0.53, _12=0.29, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=85, Team='Away', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=6863, _6=274.52, _7=6863, _8=274.52, From='Player21', To=nan, _11=0.53, _12=0.29, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=86, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=6863, _6=274.52, _7=6886, _8=275.44, From='Player21', To='Player20', _11=0.53, _12=0.29, _13=0.54, _14=0.37)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=87, Team='Home', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=6864, _6=274.56, _7=6885, _8=275.4, From='Player6', To=nan, _11=0.54, _12=0.3, _13=0.55, _14=0.37)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=88, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=6905, _6=276.2, _7=6946, _8=277.84, From='Player20', To='Player22', _11=0.52, _12=0.41, _13=0.46, _14=0.78)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=89, Team='Away', Type='BALL LOST', Subtype='CROSS-INTERCEPTION', Period=1, _5=6987, _6=279.48, _7=7043, _8=281.72, From='Player22', To=nan, _11=0.38, _12=0.84, _13=0.08, _14=0.4)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=90, Team='Home', Type='CHALLENGE', Subtype='GROUND-WON', Period=1, _5=7041, _6=281.64, _7=7041, _8=281.64, From='Player3', To=nan, _11=0.1, _12=0.42, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=91, Team='Home', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=7041, _6=281.64, _7=7041, _8=281.64, From='Player3', To=nan, _11=0.1, _12=0.42, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=92, Team='Home', Type='PASS', Subtype=nan, Period=1, _5=7041, _6=281.64, _7=7148, _8=285.92, From='Player3', To='Player4', _11=0.1, _12=0.42, _13=0.03, _14=0.03)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=93, Team='Away', Type='CHALLENGE', Subtype='GROUND-LOST', Period=1, _5=7043, _6=281.72, _7=7043, _8=281.72, From='Player24', To=nan, _11=0.1, _12=0.39, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=94, Team='Home', Type='BALL LOST', Subtype=nan, Period=1, _5=7199, _6=287.96, _7=7204, _8=288.16, From='Player4', To=nan, _11=0.1, _12=0.01, _13=0.14, _14=0.02)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=95, Team='Away', Type='RECOVERY', Subtype=nan, Period=1, _5=7203, _6=288.12, _7=7203, _8=288.12, From='Player18', To=nan, _11=0.13, _12=0.01, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=96, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=7203, _6=288.12, _7=7266, _8=290.64, From='Player18', To='Player21', _11=0.13, _12=0.01, _13=0.2, _14=0.11)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=97, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=7266, _6=290.64, _7=7290, _8=291.6, From='Player21', To='Player18', _11=0.2, _12=0.11, _13=0.18, _14=0.04)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=98, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=7334, _6=293.36, _7=7387, _8=295.48, From='Player18', To='Player15', _11=0.24, _12=0.02, _13=0.38, _14=0.08)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=99, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=7404, _6=296.16, _7=7427, _8=297.08, From='Player15', To='Player23', _11=0.38, _12=0.08, _13=0.25, _14=0.21)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=100, Team='Away', Type='BALL LOST', Subtype=nan, Period=1, _5=7465, _6=298.6, _7=7470, _8=298.8, From='Player23', To=nan, _11=0.23, _12=0.26, _13=0.21, _14=0.26)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=101, Team='Home', Type='RECOVERY', Subtype=nan, Period=1, _5=7472, _6=298.88, _7=7472, _8=298.88, From='Player3', To=nan, _11=0.2, _12=0.29, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=102, Team='Home', Type='BALL LOST', Subtype=nan, Period=1, _5=7472, _6=298.88, _7=7518, _8=300.72, From='Player3', To=nan, _11=0.2, _12=0.29, _13=0.26, _14=0.26)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=103, Team='Away', Type='RECOVERY', Subtype=nan, Period=1, _5=7519, _6=300.76, _7=7519, _8=300.76, From='Player19', To=nan, _11=0.26, _12=0.29, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=104, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=7519, _6=300.76, _7=7556, _8=302.24, From='Player19', To='Player18', _11=0.26, _12=0.29, _13=0.29, _14=0.07)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=105, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=7603, _6=304.12, _7=7632, _8=305.28, From='Player18', To='Player19', _11=0.29, _12=0.07, _13=0.3, _14=0.24)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=106, Team='Away', Type='CHALLENGE', Subtype='TACKLE-LOST', Period=1, _5=7698, _6=307.92, _7=7698, _8=307.92, From='Player19', To=nan, _11=0.24, _12=0.22, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=107, Team='Away', Type='BALL LOST', Subtype='THEFT', Period=1, _5=7698, _6=307.92, _7=7698, _8=307.92, From='Player19', To=nan, _11=0.24, _12=0.22, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=108, Team='Home', Type='CHALLENGE', Subtype='TACKLE-LOST', Period=1, _5=7699, _6=307.96, _7=7699, _8=307.96, From='Player8', To=nan, _11=0.22, _12=0.17, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=109, Team='Away', Type='RECOVERY', Subtype=nan, Period=1, _5=7724, _6=308.96, _7=7724, _8=308.96, From='Player21', To=nan, _11=0.19, _12=0.27, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=110, Team='Away', Type='SHOT', Subtype='OFF TARGET-OUT', Period=1, _5=7753, _6=310.12, _7=7789, _8=311.56, From='Player21', To=nan, _11=0.2, _12=0.3, _13=-0.04, _14=0.65)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=111, Team='Home', Type='RECOVERY', Subtype=nan, Period=1, _5=8482, _6=339.28, _7=8482, _8=339.28, From='Player11', To=nan, _11=0.04, _12=0.52, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=112, Team='Home', Type='BALL LOST', Subtype='GOAL KICK-INTERCEPTION', Period=1, _5=8482, _6=339.28, _7=8576, _8=343.04, From='Player11', To=nan, _11=0.04, _12=0.52, _13=0.64, _14=0.38)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=113, Team='Away', Type='CHALLENGE', Subtype='AERIAL-WON', Period=1, _5=8576, _6=343.04, _7=8576, _8=343.04, From='Player15', To=nan, _11=0.62, _12=0.36, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=114, Team='Away', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=8576, _6=343.04, _7=8576, _8=343.04, From='Player15', To=nan, _11=0.62, _12=0.36, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=115, Team='Away', Type='BALL LOST', Subtype='HEAD', Period=1, _5=8576, _6=343.04, _7=8580, _8=343.2, From='Player15', To=nan, _11=0.62, _12=0.36, _13=0.63, _14=0.36)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=116, Team='Home', Type='RECOVERY', Subtype=nan, Period=1, _5=8581, _6=343.24, _7=8581, _8=343.24, From='Player10', To=nan, _11=0.6, _12=0.37, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=117, Team='Home', Type='BALL LOST', Subtype='HEAD', Period=1, _5=8581, _6=343.24, _7=8652, _8=346.08, From='Player10', To=nan, _11=0.6, _12=0.37, _13=0.68, _14=0.35)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=118, Team='Away', Type='RECOVERY', Subtype=nan, Period=1, _5=8650, _6=346.0, _7=8650, _8=346.0, From='Player15', To=nan, _11=0.66, _12=0.35, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=119, Team='Away', Type='PASS', Subtype='HEAD', Period=1, _5=8650, _6=346.0, _7=8686, _8=347.44, From='Player15', To='Player16', _11=0.66, _12=0.35, _13=0.75, _14=0.38)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=120, Team='Away', Type='BALL LOST', Subtype=nan, Period=1, _5=8686, _6=347.44, _7=8735, _8=349.4, From='Player16', To=nan, _11=0.75, _12=0.38, _13=0.64, _14=0.28)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=121, Team='Home', Type='RECOVERY', Subtype=nan, Period=1, _5=8734, _6=349.36, _7=8734, _8=349.36, From='Player8', To=nan, _11=0.64, _12=0.23, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=122, Team='Home', Type='BALL OUT', Subtype=nan, Period=1, _5=8753, _6=350.12, _7=8843, _8=353.72, From='Player8', To=nan, _11=0.65, _12=0.21, _13=0.74, _14=-0.04)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=123, Team='Away', Type='SET PIECE', Subtype='THROW IN', Period=1, _5=8868, _6=354.72, _7=8868, _8=354.72, From='Player18', To=nan, _11=nan, _12=nan, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=124, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=8868, _6=354.72, _7=8892, _8=355.68, From='Player18', To='Player19', _11=0.77, _12=-0.01, _13=0.72, _14=0.1)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=125, Team='Away', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=8937, _6=357.48, _7=9068, _8=362.72, From='Player19', To=nan, _11=0.71, _12=0.11, _13=0.08, _14=0.17)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=126, Team='Home', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=9069, _6=362.76, _7=9069, _8=362.76, From='Player3', To=nan, _11=0.09, _12=0.14, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=127, Team='Home', Type='BALL OUT', Subtype=nan, Period=1, _5=9098, _6=363.92, _7=9127, _8=365.08, From='Player3', To=nan, _11=0.02, _12=0.1, _13=0.05, _14=-0.04)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=128, Team='Away', Type='SET PIECE', Subtype='THROW IN', Period=1, _5=9215, _6=368.6, _7=9215, _8=368.6, From='Player23', To=nan, _11=nan, _12=nan, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=129, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=9215, _6=368.6, _7=9255, _8=370.2, From='Player23', To='Player18', _11=0.06, _12=0.0, _13=0.22, _14=0.06)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=130, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=9306, _6=372.24, _7=9337, _8=373.48, From='Player18', To='Player19', _11=0.18, _12=0.11, _13=0.24, _14=0.3)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=131, Team='Away', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=9337, _6=373.48, _7=9356, _8=374.24, From='Player19', To=nan, _11=0.24, _12=0.3, _13=0.24, _14=0.39)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=132, Team='Home', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=9354, _6=374.16, _7=9354, _8=374.16, From='Player6', To=nan, _11=0.22, _12=0.36, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=133, Team='Home', Type='PASS', Subtype=nan, Period=1, _5=9390, _6=375.6, _7=9442, _8=377.68, From='Player6', To='Player10', _11=0.29, _12=0.38, _13=0.55, _14=0.13)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=134, Team='Home', Type='PASS', Subtype='DEEP BALL', Period=1, _5=9599, _6=383.96, _7=9628, _8=385.12, From='Player10', To='Player8', _11=0.87, _12=0.29, _13=0.96, _14=0.37)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=135, Team='Home', Type='SHOT', Subtype='ON TARGET-SAVED', Period=1, _5=9628, _6=385.12, _7=9632, _8=385.28, From='Player8', To=nan, _11=0.96, _12=0.37, _13=0.98, _14=0.46)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=136, Team='Away', Type='RECOVERY', Subtype='SAVED', Period=1, _5=9634, _6=385.36, _7=9634, _8=385.36, From='Player25', To=nan, _11=0.97, _12=0.44, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=137, Team='Away', Type='BALL OUT', Subtype=nan, Period=1, _5=9634, _6=385.36, _7=9663, _8=386.52, From='Player25', To=nan, _11=0.97, _12=0.44, _13=1.03, _14=0.33)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=138, Team='Home', Type='SET PIECE', Subtype='CORNER KICK', Period=1, _5=10387, _6=415.48, _7=10387, _8=415.48, From='Player6', To=nan, _11=nan, _12=nan, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=139, Team='Home', Type='PASS', Subtype=nan, Period=1, _5=10387, _6=415.48, _7=10418, _8=416.72, From='Player6', To='Player10', _11=0.99, _12=0.01, _13=0.94, _14=0.09)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=140, Team='Home', Type='PASS', Subtype=nan, Period=1, _5=10453, _6=418.12, _7=10477, _8=419.08, From='Player10', To='Player6', _11=0.94, _12=0.09, _13=0.87, _14=0.1)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=141, Team='Home', Type='PASS', Subtype=nan, Period=1, _5=10493, _6=419.72, _7=10527, _8=421.08, From='Player6', To='Player5', _11=0.86, _12=0.11, _13=0.78, _14=0.36)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=142, Team='Home', Type='PASS', Subtype=nan, Period=1, _5=10551, _6=422.04, _7=10599, _8=423.96, From='Player5', To='Player7', _11=0.79, _12=0.36, _13=0.74, _14=0.64)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=143, Team='Home', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=10613, _6=424.52, _7=10651, _8=426.04, From='Player7', To=nan, _11=0.75, _12=0.65, _13=0.92, _14=0.46)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=144, Team='Away', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=10653, _6=426.12, _7=10653, _8=426.12, From='Player15', To=nan, _11=0.91, _12=0.47, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=145, Team='Away', Type='BALL LOST', Subtype='HEAD-INTERCEPTION', Period=1, _5=10653, _6=426.12, _7=10709, _8=428.36, From='Player15', To=nan, _11=0.91, _12=0.47, _13=0.83, _14=0.52)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=146, Team='Home', Type='CHALLENGE', Subtype='AERIAL-WON', Period=1, _5=10708, _6=428.32, _7=10708, _8=428.32, From='Player8', To=nan, _11=0.83, _12=0.51, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=147, Team='Home', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=10708, _6=428.32, _7=10708, _8=428.32, From='Player8', To=nan, _11=0.83, _12=0.51, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=148, Team='Home', Type='PASS', Subtype='HEAD', Period=1, _5=10708, _6=428.32, _7=10742, _8=429.68, From='Player8', To='Player3', _11=0.83, _12=0.51, _13=0.83, _14=0.54)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=149, Team='Away', Type='CHALLENGE', Subtype='AERIAL-LOST', Period=1, _5=10709, _6=428.36, _7=10709, _8=428.36, From='Player22', To=nan, _11=0.84, _12=0.51, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=150, Team='Home', Type='BALL LOST', Subtype='HEAD-INTERCEPTION', Period=1, _5=10742, _6=429.68, _7=10761, _8=430.44, From='Player3', To=nan, _11=0.83, _12=0.54, _13=0.87, _14=0.45)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=151, Team='Away', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=10761, _6=430.44, _7=10761, _8=430.44, From='Player15', To=nan, _11=0.86, _12=0.47, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=152, Team='Away', Type='BALL LOST', Subtype='HEAD-FORCED', Period=1, _5=10761, _6=430.44, _7=10801, _8=432.04, From='Player15', To=nan, _11=0.86, _12=0.47, _13=0.78, _14=0.65)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=153, Team='Home', Type='CHALLENGE', Subtype='AERIAL-FAULT-LOST', Period=1, _5=10801, _6=432.04, _7=10801, _8=432.04, From='Player2', To=nan, _11=0.76, _12=0.65, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=154, Team='Away', Type='CHALLENGE', Subtype='AERIAL-FAULT-WON', Period=1, _5=10801, _6=432.04, _7=10801, _8=432.04, From='Player21', To=nan, _11=0.76, _12=0.65, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=155, Team='Away', Type='SET PIECE', Subtype='FREE KICK', Period=1, _5=11586, _6=463.44, _7=11586, _8=463.44, From='Player25', To=nan, _11=nan, _12=nan, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=156, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=11586, _6=463.44, _7=11619, _8=464.76, From='Player25', To='Player17', _11=0.78, _12=0.55, _13=0.7, _14=0.79)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=157, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=11674, _6=466.96, _7=11701, _8=468.04, From='Player17', To='Player22', _11=0.65, _12=0.83, _13=0.57, _14=0.97)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=158, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=11727, _6=469.08, _7=11763, _8=470.52, From='Player22', To='Player20', _11=0.58, _12=0.94, _13=0.54, _14=0.73)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=159, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=11788, _6=471.52, _7=11812, _8=472.48, From='Player20', To='Player19', _11=0.53, _12=0.71, _13=0.5, _14=0.52)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=160, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=11831, _6=473.24, _7=11861, _8=474.44, From='Player19', To='Player24', _11=0.5, _12=0.55, _13=0.39, _14=0.4)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=161, Team='Away', Type='PASS', Subtype=nan, Period=1, _5=11882, _6=475.28, _7=11918, _8=476.72, From='Player24', To='Player18', _11=0.39, _12=0.41, _13=0.32, _14=0.1)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=162, Team='Away', Type='BALL LOST', Subtype='CROSS-INTERCEPTION', Period=1, _5=11987, _6=479.48, _7=12032, _8=481.28, From='Player18', To=nan, _11=0.22, _12=0.12, _13=0.03, _14=0.61)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=163, Team='Home', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=12033, _6=481.32, _7=12033, _8=481.32, From='Player1', To=nan, _11=0.04, _12=0.62, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=164, Team='Home', Type='BALL OUT', Subtype='HEAD-CLEARANCE', Period=1, _5=12033, _6=481.32, _7=12047, _8=481.88, From='Player1', To=nan, _11=0.04, _12=0.62, _13=-0.05, _14=0.71)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=165, Team='Away', Type='SET PIECE', Subtype='CORNER KICK', Period=1, _5=12636, _6=505.44, _7=12636, _8=505.44, From='Player21', To=nan, _11=nan, _12=nan, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=166, Team='Away', Type='BALL OUT', Subtype=nan, Period=1, _5=12636, _6=505.44, _7=12702, _8=508.08, From='Player21', To=nan, _11=0.01, _12=0.95, _13=-0.03, _14=0.34)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=167, Team='Home', Type='RECOVERY', Subtype=nan, Period=1, _5=13543, _6=541.72, _7=13543, _8=541.72, From='Player11', To=nan, _11=0.04, _12=0.44, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=168, Team='Home', Type='PASS', Subtype='GOAL KICK', Period=1, _5=13543, _6=541.72, _7=13625, _8=545.0, From='Player11', To='Player5', _11=0.04, _12=0.44, _13=0.5, _14=0.86)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=169, Team='Home', Type='PASS', Subtype=nan, Period=1, _5=13625, _6=545.0, _7=13641, _8=545.64, From='Player5', To='Player1', _11=0.5, _12=0.86, _13=0.42, _14=0.84)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=170, Team='Home', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=13672, _6=546.88, _7=13701, _8=548.04, From='Player1', To=nan, _11=0.41, _12=0.85, _13=0.63, _14=0.86)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=171, Team='Away', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=13701, _6=548.04, _7=13701, _8=548.04, From='Player17', To=nan, _11=0.57, _12=0.86, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=172, Team='Away', Type='BALL LOST', Subtype=nan, Period=1, _5=13701, _6=548.04, _7=13736, _8=549.44, From='Player17', To=nan, _11=0.57, _12=0.86, _13=0.48, _14=0.82)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=173, Team='Home', Type='RECOVERY', Subtype=nan, Period=1, _5=13739, _6=549.56, _7=13739, _8=549.56, From='Player6', To=nan, _11=0.48, _12=0.79, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=174, Team='Home', Type='BALL LOST', Subtype='INTERCEPTION', Period=1, _5=13739, _6=549.56, _7=13766, _8=550.64, From='Player6', To=nan, _11=0.48, _12=0.79, _13=0.68, _14=0.53)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=175, Team='Away', Type='RECOVERY', Subtype='INTERCEPTION', Period=1, _5=13766, _6=550.64, _7=13766, _8=550.64, From='Player15', To=nan, _11=0.64, _12=0.55, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=176, Team='Away', Type='BALL LOST', Subtype=nan, Period=1, _5=13766, _6=550.64, _7=13814, _8=552.56, From='Player15', To=nan, _11=0.64, _12=0.55, _13=0.76, _14=0.52)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=177, Team='Home', Type='RECOVERY', Subtype=nan, Period=1, _5=13814, _6=552.56, _7=13814, _8=552.56, From='Player9', To=nan, _11=0.73, _12=0.56, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=178, Team='Home', Type='CHALLENGE', Subtype='TACKLE-LOST', Period=1, _5=13843, _6=553.72, _7=13843, _8=553.72, From='Player9', To=nan, _11=0.8, _12=0.52, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=179, Team='Home', Type='BALL LOST', Subtype='THEFT', Period=1, _5=13843, _6=553.72, _7=13843, _8=553.72, From='Player9', To=nan, _11=0.8, _12=0.52, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=180, Team='Away', Type='CHALLENGE', Subtype='TACKLE-WON', Period=1, _5=13844, _6=553.76, _7=13844, _8=553.76, From='Player16', To=nan, _11=0.81, _12=0.53, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# ...
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1687, Team='Home', Type='PASS', Subtype=nan, Period=2, _5=138647, _6=5545.88, _7=138675, _8=5547.0, From='Player2', To='Player14', _11=0.66, _12=0.4, _13=0.49, _14=0.17)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1688, Team='Home', Type='PASS', Subtype=nan, Period=2, _5=138684, _6=5547.36, _7=138729, _8=5549.16, From='Player14', To='Player12', _11=0.5, _12=0.17, _13=0.57, _14=0.31)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1689, Team='Home', Type='PASS', Subtype=nan, Period=2, _5=138761, _6=5550.44, _7=138794, _8=5551.76, From='Player12', To='Player3', _11=0.56, _12=0.35, _13=0.64, _14=0.63)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1690, Team='Home', Type='PASS', Subtype=nan, Period=2, _5=138846, _6=5553.84, _7=138871, _8=5554.84, From='Player3', To='Player5', _11=0.62, _12=0.67, _13=0.55, _14=0.57)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1691, Team='Home', Type='PASS', Subtype=nan, Period=2, _5=138929, _6=5557.16, _7=138954, _8=5558.16, From='Player5', To='Player2', _11=0.57, _12=0.56, _13=0.64, _14=0.32)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1692, Team='Home', Type='PASS', Subtype=nan, Period=2, _5=138986, _6=5559.44, _7=139011, _8=5560.44, From='Player2', To='Player7', _11=0.65, _12=0.24, _13=0.57, _14=0.06)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1693, Team='Home', Type='PASS', Subtype=nan, Period=2, _5=139029, _6=5561.16, _7=139044, _8=5561.76, From='Player7', To='Player12', _11=0.58, _12=0.05, _13=0.57, _14=0.23)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1694, Team='Home', Type='PASS', Subtype=nan, Period=2, _5=139089, _6=5563.56, _7=139101, _8=5564.04, From='Player12', To='Player13', _11=0.59, _12=0.18, _13=0.51, _14=0.09)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1695, Team='Away', Type='CHALLENGE', Subtype='TACKLE-FAULT-LOST', Period=2, _5=139110, _6=5564.4, _7=139110, _8=5564.4, From='Player20', To=nan, _11=0.51, _12=0.09, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1696, Team='Home', Type='CHALLENGE', Subtype='TACKLE-FAULT-WON', Period=2, _5=139133, _6=5565.32, _7=139133, _8=5565.32, From='Player13', To=nan, _11=0.53, _12=0.09, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1697, Team='Home', Type='FAULT RECEIVED', Subtype=nan, Period=2, _5=139133, _6=5565.32, _7=139133, _8=5565.32, From='Player13', To=nan, _11=0.53, _12=0.09, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1698, Team='Home', Type='SET PIECE', Subtype='FREE KICK', Period=2, _5=139568, _6=5582.72, _7=139568, _8=5582.72, From='Player12', To=nan, _11=nan, _12=nan, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1699, Team='Home', Type='PASS', Subtype=nan, Period=2, _5=139571, _6=5582.84, _7=139596, _8=5583.84, From='Player12', To='Player2', _11=0.52, _12=0.21, _13=0.65, _14=0.26)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1700, Team='Home', Type='PASS', Subtype=nan, Period=2, _5=139629, _6=5585.16, _7=139667, _8=5586.68, From='Player2', To='Player3', _11=0.66, _12=0.26, _13=0.71, _14=0.54)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1701, Team='Home', Type='PASS', Subtype=nan, Period=2, _5=139724, _6=5588.96, _7=139754, _8=5590.16, From='Player3', To='Player2', _11=0.71, _12=0.47, _13=0.75, _14=0.19)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1702, Team='Home', Type='PASS', Subtype=nan, Period=2, _5=139782, _6=5591.28, _7=139804, _8=5592.16, From='Player2', To='Player7', _11=0.75, _12=0.14, _13=0.66, _14=0.03)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1703, Team='Home', Type='PASS', Subtype=nan, Period=2, _5=139824, _6=5592.96, _7=139852, _8=5594.08, From='Player7', To='Player14', _11=0.66, _12=0.03, _13=0.56, _14=0.15)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1704, Team='Away', Type='CHALLENGE', Subtype='TACKLE-WON', Period=2, _5=139851, _6=5594.04, _7=139851, _8=5594.04, From='Player28', To=nan, _11=0.61, _12=0.17, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1705, Team='Away', Type='RECOVERY', Subtype='THEFT', Period=2, _5=139851, _6=5594.04, _7=139851, _8=5594.04, From='Player28', To=nan, _11=0.61, _12=0.17, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1706, Team='Home', Type='BALL LOST', Subtype='INTERCEPTION', Period=2, _5=139857, _6=5594.28, _7=139860, _8=5594.4, From='Player14', To=nan, _11=0.57, _12=0.16, _13=0.62, _14=0.25)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1707, Team='Away', Type='PASS', Subtype=nan, Period=2, _5=139867, _6=5594.68, _7=139874, _8=5594.96, From='Player28', To='Player21', _11=0.59, _12=0.16, _13=0.57, _14=0.25)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1708, Team='Away', Type='PASS', Subtype=nan, Period=2, _5=139898, _6=5595.92, _7=139943, _8=5597.72, From='Player21', To='Player26', _11=0.57, _12=0.25, _13=0.71, _14=0.18)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1709, Team='Away', Type='BALL OUT', Subtype=nan, Period=2, _5=140057, _6=5602.28, _7=140112, _8=5604.48, From='Player26', To=nan, _11=0.74, _12=0.45, _13=1.02, _14=0.71)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1710, Team='Home', Type='RECOVERY', Subtype=nan, Period=2, _5=140135, _6=5605.4, _7=140135, _8=5605.4, From='Player11', To=nan, _11=0.98, _12=0.52, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1711, Team='Home', Type='PASS', Subtype='GOAL KICK', Period=2, _5=140478, _6=5619.12, _7=140496, _8=5619.84, From='Player11', To='Player7', _11=0.96, _12=0.52, _13=0.84, _14=0.19)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1712, Team='Home', Type='BALL LOST', Subtype='INTERCEPTION', Period=2, _5=140619, _6=5624.76, _7=140681, _8=5627.24, From='Player7', To=nan, _11=0.72, _12=0.11, _13=0.42, _14=0.17)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1713, Team='Away', Type='RECOVERY', Subtype='INTERCEPTION', Period=2, _5=140675, _6=5627.0, _7=140675, _8=5627.0, From='Player20', To=nan, _11=0.41, _12=0.15, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1714, Team='Away', Type='PASS', Subtype=nan, Period=2, _5=140729, _6=5629.16, _7=140744, _8=5629.76, From='Player20', To='Player28', _11=0.42, _12=0.04, _13=0.5, _14=0.15)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1715, Team='Home', Type='CHALLENGE', Subtype='TACKLE-FAULT-LOST', Period=2, _5=140893, _6=5635.72, _7=140893, _8=5635.72, From='Player14', To=nan, _11=0.56, _12=0.41, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1716, Team='Away', Type='CHALLENGE', Subtype='TACKLE-FAULT-WON', Period=2, _5=140912, _6=5636.48, _7=140912, _8=5636.48, From='Player28', To=nan, _11=0.6, _12=0.45, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1717, Team='Away', Type='FAULT RECEIVED', Subtype=nan, Period=2, _5=140912, _6=5636.48, _7=140912, _8=5636.48, From='Player28', To=nan, _11=0.6, _12=0.45, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1718, Team='Away', Type='SET PIECE', Subtype='FREE KICK', Period=2, _5=141137, _6=5645.48, _7=141137, _8=5645.48, From='Player21', To=nan, _11=nan, _12=nan, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1719, Team='Away', Type='PASS', Subtype=nan, Period=2, _5=141140, _6=5645.6, _7=141148, _8=5645.92, From='Player21', To='Player28', _11=0.61, _12=0.43, _13=0.64, _14=0.43)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1720, Team='Away', Type='PASS', Subtype=nan, Period=2, _5=141185, _6=5647.4, _7=141230, _8=5649.2, From='Player28', To='Player27', _11=0.66, _12=0.42, _13=0.77, _14=0.06)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1721, Team='Home', Type='CHALLENGE', Subtype='TACKLE-LOST', Period=2, _5=141404, _6=5656.16, _7=141404, _8=5656.16, From='Player14', To=nan, _11=0.87, _12=0.11, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1722, Team='Away', Type='PASS', Subtype=nan, Period=2, _5=141436, _6=5657.44, _7=141451, _8=5658.04, From='Player27', To='Player28', _11=0.86, _12=0.03, _13=0.78, _14=0.13)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1723, Team='Away', Type='BALL OUT', Subtype=nan, Period=2, _5=141541, _6=5661.64, _7=141548, _8=5661.92, From='Player28', To=nan, _11=0.79, _12=0.18, _13=1.02, _14=0.33)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1724, Team='Home', Type='RECOVERY', Subtype=nan, Period=2, _5=141552, _6=5662.08, _7=141552, _8=5662.08, From='Player11', To=nan, _11=0.99, _12=0.42, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1725, Team='Home', Type='BALL OUT', Subtype='GOAL KICK', Period=2, _5=142259, _6=5690.36, _7=142394, _8=5695.76, From='Player11', To=nan, _11=0.97, _12=0.47, _13=0.38, _14=1.02)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1726, Team='Home', Type='CHALLENGE', Subtype='AERIAL-LOST', Period=2, _5=142394, _6=5695.76, _7=142394, _8=5695.76, From='Player8', To=nan, _11=0.47, _12=0.92, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1727, Team='Away', Type='SET PIECE', Subtype='THROW IN', Period=2, _5=142516, _6=5700.64, _7=142516, _8=5700.64, From='Player17', To=nan, _11=nan, _12=nan, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1728, Team='Away', Type='PASS', Subtype=nan, Period=2, _5=142526, _6=5701.04, _7=142554, _8=5702.16, From='Player17', To='Player21', _11=0.49, _12=1.01, _13=0.44, _14=0.77)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1729, Team='Away', Type='PASS', Subtype=nan, Period=2, _5=142615, _6=5704.6, _7=142648, _8=5705.92, From='Player21', To='Player16', _11=0.42, _12=0.72, _13=0.32, _14=0.64)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1730, Team='Away', Type='PASS', Subtype=nan, Period=2, _5=142665, _6=5706.6, _7=142695, _8=5707.8, From='Player16', To='Player20', _11=0.32, _12=0.63, _13=0.39, _14=0.35)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1731, Team='Away', Type='PASS', Subtype=nan, Period=2, _5=142715, _6=5708.6, _7=142755, _8=5710.2, From='Player20', To='Player27', _11=0.41, _12=0.33, _13=0.6, _14=0.04)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1732, Team='Away', Type='BALL LOST', Subtype='INTERCEPTION', Period=2, _5=142886, _6=5715.44, _7=142938, _8=5717.52, From='Player27', To=nan, _11=0.72, _12=0.08, _13=0.85, _14=0.32)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1733, Team='Home', Type='RECOVERY', Subtype='INTERCEPTION', Period=2, _5=142938, _6=5717.52, _7=142938, _8=5717.52, From='Player2', To=nan, _11=0.85, _12=0.32, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1734, Team='Home', Type='BALL LOST', Subtype='CLEARANCE', Period=2, _5=142943, _6=5717.72, _7=143008, _8=5720.32, From='Player2', To=nan, _11=0.85, _12=0.32, _13=0.48, _14=0.34)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1735, Team='Away', Type='RECOVERY', Subtype='INTERCEPTION', Period=2, _5=143013, _6=5720.52, _7=143013, _8=5720.52, From='Player16', To=nan, _11=0.47, _12=0.37, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1736, Team='Away', Type='PASS', Subtype=nan, Period=2, _5=143130, _6=5725.2, _7=143137, _8=5725.48, From='Player16', To='Player18', _11=0.5, _12=0.37, _13=0.61, _14=0.53)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1737, Team='Away', Type='BALL LOST', Subtype='INTERCEPTION', Period=2, _5=143229, _6=5729.16, _7=143247, _8=5729.88, From='Player18', To=nan, _11=0.68, _12=0.3, _13=0.77, _14=0.23)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1738, Team='Home', Type='RECOVERY', Subtype='INTERCEPTION', Period=2, _5=143240, _6=5729.6, _7=143240, _8=5729.6, From='Player14', To=nan, _11=0.74, _12=0.22, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1739, Team='Home', Type='PASS', Subtype=nan, Period=2, _5=143262, _6=5730.48, _7=143297, _8=5731.88, From='Player14', To='Player12', _11=0.75, _12=0.22, _13=0.71, _14=0.28)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1740, Team='Home', Type='PASS', Subtype=nan, Period=2, _5=143361, _6=5734.44, _7=143483, _8=5739.32, From='Player12', To='Player13', _11=0.6, _12=0.33, _13=0.19, _14=0.95)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1741, Team='Home', Type='PASS', Subtype=nan, Period=2, _5=143578, _6=5743.12, _7=143593, _8=5743.72, From='Player13', To='Player4', _11=0.09, _12=0.88, _13=0.14, _14=0.69)
# type <class 'str'>
# Hello1
# toPlayer <class 'py2neo.data.Node'>
# HEllo2
# Hello3
# Hello4
# Event Done
# Pandas(Index=1742, Team='Home', Type='BALL LOST', Subtype='INTERCEPTION', Period=2, _5=143598, _6=5743.92, _7=143618, _8=5744.72, From='Player4', To=nan, _11=0.13, _12=0.69, _13=0.07, _14=0.61)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1743, Team='Away', Type='RECOVERY', Subtype='BLOCKED', Period=2, _5=143617, _6=5744.68, _7=143617, _8=5744.68, From='Player16', To=nan, _11=0.05, _12=0.62, _13=nan, _14=nan)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done
# Pandas(Index=1744, Team='Away', Type='BALL OUT', Subtype=nan, Period=2, _5=143622, _6=5744.88, _7=143630, _8=5745.2, From='Player16', To=nan, _11=0.05, _12=0.63, _13=0.03, _14=1.01)
# type <class 'float'>
# Hello1
# toPlayer <class 'NoneType'>
# HEllo2
# Hello3
# Event Done

# %% [markdown]
# # 6. Getting Data from the graph

# %% [markdown]
# ## 6.1 Who is the most active player (in terms of passing and receiving the ball)?

# %% [markdown]
# We count the amount of PASS relationship to and from each player node

# %%
activity_result=graph.run("MATCH(player:player)-[event:PASS]-(:PASS) WITH player, COUNT(event) AS num ORDER BY num DESC RETURN player.name,num")
df = pd.DataFrame(activity_result)
df
# Out:
#            0    1
# 0   Player21  135
# 1   Player12  106
# 2    Player7  102
# 3    Player4   89
# 4   Player19   85
# 5    Player2   84
# 6    Player6   83
# 7   Player17   80
# 8    Player8   76
# 9    Player3   74
# 10  Player16   71
# 11  Player10   70
# 12   Player5   69
# 13  Player20   66
# 14  Player22   61
# 15  Player15   57
# 16  Player18   55
# 17   Player9   44
# 18  Player25   27
# 19  Player23   27
# 20  Player11   25
# 21  Player27   25
# 22  Player14   20
# 23   Player1   17
# 24  Player28   17
# 25  Player13   15
# 26  Player24   14
# 27  Player26    4

# %% [markdown]
# #### Answer:
# Player21 is the most active player in terms of passing and recieving the ball with a total of 135 PASS events related to him/her.

# %% [markdown]
# ## 6.2 who has had a central role in the match?

# %% [markdown]
# we count the total amount of relationships each players have to find the most active player.
# one could argue that some events are worth more than others, however in this case we count the equally.

# %%
activity_result=graph.run("MATCH(player:player)-[event]-() WITH player, COUNT(event) AS num ORDER BY num DESC RETURN player.name,num")
df = pd.DataFrame(activity_result)
df
# Out:
#            0    1
# 0   Player21  172
# 1   Player19  149
# 2    Player7  149
# 3    Player8  137
# 4   Player12  135
# 5   Player17  134
# 6    Player6  130
# 7    Player2  129
# 8    Player4  123
# 9    Player3  117
# 10  Player16  116
# 11  Player15  109
# 12  Player22  105
# 13  Player10  103
# 14   Player5   98
# 15  Player18   95
# 16  Player20   94
# 17   Player9   81
# 18  Player25   62
# 19  Player11   62
# 20  Player23   46
# 21  Player27   37
# 22   Player1   37
# 23  Player14   34
# 24  Player28   28
# 25  Player24   27
# 26  Player13   19
# 27  Player26   16

# %% [markdown]
# #### Answer
# We see that player21 has the most relationships, we therefore conclude that he/she had the biggest impact on the match

# %% [markdown]
# ## 6.3 which players have attempted to score?

# %% [markdown]
# We count the amount of SHOT reltionships for each player

# %%
activity_result=graph.run("MATCH(player:player)-[event:SHOT]-(:SHOT) WITH player, COUNT(event) AS num ORDER BY num DESC RETURN player.name,num")
df = pd.DataFrame(activity_result)
df
# Out:
#            0  1
# 0    Player9  4
# 1   Player10  4
# 2    Player8  4
# 3    Player7  2
# 4    Player5  2
# 5   Player21  1
# 6   Player24  1
# 7   Player19  1
# 8   Player12  1
# 9   Player27  1
# 10  Player14  1
# 11  Player23  1
# 12  Player28  1

# %%
activity_result=graph.run("MATCH(player:player)-[event:SHOT]-(eventNode:SHOT) WHERE eventNode.subtype CONTAINS 'GOAL' WITH player, COUNT(event) AS num ORDER BY num DESC RETURN player.name,num")
df = pd.DataFrame(activity_result)
df
# Out:
#           0  1
# 0   Player9  2
# 1  Player10  1

# %% [markdown]
# #### Answer
# Quite a few players have tried to score goals, player9 and player10 both succeeded in goals and the match ended 3-0

# %% [markdown]
# ## 6.4  which team has kept the ball longer?

# %% [markdown]
# We add up the start minus the end time and sum them together for each team

# %%
activity_result_away=graph.run("MATCH (p:player)-[:PASS]->(e:PASS)-[:PASS]->(p2:player) WHERE e.team = 'Away' RETURN sum(toInteger(e.endtime) - toInteger(e.starttime))")
activity_result_away
# Out:
#  sum(toInteger(e.endtime) - toInteger(e.starttime))
# ----------------------------------------------------
#                                                 491

# %%
activity_result_Home=graph.run("MATCH (p:player)-[:PASS]->(e:PASS)-[:PASS]->(p2:player) WHERE e.team = 'Home' RETURN sum(toInteger(e.endtime) - toInteger(e.starttime))")
activity_result_Home
# Out:
#  sum(toInteger(e.endtime) - toInteger(e.starttime))
# ----------------------------------------------------
#                                                 613

# %% [markdown]
# #### Answer
# We can see that the home team has had to ball for more time than the away team

# %% [markdown]
# ## 6.5  is there any close ‘societies’ between players (passing the ball to each other)?

# %% [markdown]
# we count the amount of PASS relationships between two players

# %%
activity_result=graph.run("MATCH(player:player)-[event:PASS]-(:PASS)-[r2:PASS]-(toPlayer:player)WITH player, toPlayer,COUNT(event) AS num ORDER BY num DESC RETURN player.name, toPlayer.name, num")
df = pd.DataFrame(activity_result)
df.head(10)
# Out:
#           0         1   2
# 0   Player7   Player2  25
# 1   Player2   Player7  25
# 2  Player21  Player19  24
# 3  Player19  Player21  24
# 4   Player4   Player8  23
# 5   Player8   Player4  23
# 6   Player5   Player7  19
# 7   Player7   Player5  19
# 8  Player22  Player21  18
# 9  Player21  Player22  18

# %% [markdown]
# #### Answer
# We can see that player7-player2, player21-19 and player4-player8 has the highest amount of passing the ball to eachother

# %% [markdown]
# ## 6.6  how close is the connection between two specific players?

# %% [markdown]
# Since players dont have relationship directly to eachother we will count the amount of PASS event nodes there is between two players

# %%
player1= "Player21"
player2= "Player15"
activity_result=graph.run("MATCH(player:player{name:'"+ player1 +"'})-[event:PASS]-(:PASS)-[r2:PASS]-(toPlayer:player{name:'"+ player2 +"'})WITH player, toPlayer,COUNT(event) AS num ORDER BY num DESC RETURN player.name, toPlayer.name, num")
df = pd.DataFrame(activity_result)
df.head(10)
# Out:
#           0         1   2
# 0  Player21  Player15  14

# %% [markdown]
# #### Answer
# We can see that there are 14 connection between 2 specific players, in this case player21 and player15

# %% [markdown]
# _______________________________________________________

# %%
graph.evaluate("MATCH (n) DETACH DELETE n")
